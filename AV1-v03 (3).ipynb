# %% [markdown]
# ## 2 2020 SIN176 A
# # PROGRAMAÇÃO DE COMPUTADORES PARA GESTÃO DA INFORMAÇÃO
# ## AV1 - Estruturas de dados, _Loops_ e condicionais e Funções - _Deadline_: 15/06/2021 23h00
# ---
# ### Instruções
# Este Jupyter Notebook apresenta as 10 questões. As respostas deverão ser trechos de **código Python** que solucionem as situações enunciadas.
#
# Cada questão vale 10 ponto, com a avaliação total limitada a **100 pontos**.
#
# As respostas devem ser escritas **diretamente neste Jupyter Notebook**, que deverá ser enviado em resposta à atividade de avaliação no Moodle.
#
# Nenhuma das respostas precisa ter mais do que 15 ou 20 linhas de código aproximadamente.
#
# ## Boa prova para tod@s!!!

# %% [markdown]
# ### Questão 1
# Escreva um trecho de código Python que leia três valores que representam os comprimentos das 3 arestas/lados de um triângulo. Não são quaisquer 3 valores que satisfazem os requisitos para que seja possível compor um triângulo.
#
# Para referência de como identificar um triângulo e seus tipos, utilize as seguintes [instruções](https://wagnergaspar.com/faca-um-algoritmo-que-leia-tres-valores-a-b-e-c-e-verifica-se-eles-formam-um-triangulo-com-fluxograma/).
#
#
# Os valores deverão ser pedidos até que os mesmos (este conjunto de 3 valores) formem um triângulo. Ou seja, cada tentativa deve ler um novo conjunto de 3 (três valores). Quando os valores satisfizerem os requisitos para se formar um triângulo,  o código deve 'calcular' e mostrar na tela qual é o tipo de triângulo que pode ser montado (escaleno, isósceles ou equilátero).
#
#
# **Dica**: você pode criar uma função que retorna se um trio de valores define um triângulo para usar na condição do seu _loop_.

# %%
# Escreva aqui a resposta da questão 1
# Receber os parametros
l1 = float(input("Digite o comprimento da primeira reta: "))
l2 = float(input("Digite o comprimento da segunda reta: "))
l3 = float(input("Digite o comprimento da terceira reta: "))
# Verifica se os inputs atendem o requisito para ser triangulo
if l1<l2 + l3 and l2 < l1 +l3 and l3 < l1 + l2: 
    print('Os segmentos acima podem formar um triangulo ', end='' )
    # Verifica o tipo de triangulo
    if l1 == l2 == l3:
        print ("equilatero")
    elif l1 != l2 !=l3 != l1:
        print ('escaleno')
    else:
        print ("isósceles")
else:
    # Caso os inputs nao atendam os pre requisitos
    print ("Os segmentos acima não podem formar um triangulo")

# %% [markdown]
# ### Questão 2
# Escreva uma função chamada `soma_mat()` que **recebe** duas matrizes e retorna uma matriz representando a soma matricial. Considere que as matrizes sempre serão quadradas (número de linhas igual ao número de colunas). Ou seja, 2x2, 3x3, 4x4 e assim sucessivamente.
#
# Grosso modo, a soma de matrizes ocorre da seguinte forma: se somarmos a matriz A com a matriz B de mesma ordem (no nosso caso são quadradas), A + B = C, teremos como resultado outra matriz C de mesma ordem. Para formar os elementos de C somaremos os elementos correspondentes de A e B, assim: a11 + b11 = c11.
#
# Um trecho de código Python deve ser escrito para demonstrar que a função efetivamente satisfaz suas especificações.
#
# Para referência de como executar um **produto** matricial, utilize as seguintes [instruções](https://www.blogcyberini.com/2017/09/algoritmo-multiplicacao-de-matrizes.html). Use princípios semelhantes para realizar a soma.
#
# As matrizes A e B podem ser hard code (já definidas e declaradas dentro do código) **ou** você pode fazer um loop para que o usuário defina o tipo da matriz (quadrada tamanho 2, ou tamanho 3, etc) e depois faça a entrada de dados pertinente.

# %%
# Escreva aqui a resposta da questão 2
# Matriz 2X2 pré definida
matrizA = [2,3,4,5]
matrizB = [3,4,5,6]
# Faça a soma das duas matrizes 
matrizC = [matrizA[0]+matrizB[0], matrizA[1]+matrizB[1], matrizA[2]+matrizB[2],matrizA[3]+matrizB[3]  ]
print(matrizC)

# %% [markdown]
# ### Questão 3
# Escreva uma função chamada `mult_mat()` que **recebe** duas matrizes e retorna o seu **produto**. Considere que as matrizes sempre serão quadradas (número de linhas igual ao número de colunas). Ou seja, 2x2, 3x3, 4x4 e assim sucessivamente.
#
# Para referência de como executar o produto matricial, utilize as seguintes [instruções](https://www.blogcyberini.com/2017/09/algoritmo-multiplicacao-de-matrizes.html).
#
# As matrizes A e B podem ser hard code (já definidas e declaradas dentro do código) **ou** você pode fazer um loop para que o usuário defina o tipo da matriz (quadrada tamanho 2, ou tamanho 3, etc) e depois faça a entrada de dados pertinente.

# %%
# Escreva aqui a resposta da questão 3
# Matriz 2X2 pré definida
A = [2,3,4,5]
B = [3,4,5,6]
# Faça a multiplicação das duas matrizes
C = [A[0]*B[0]+A[1]*B[2], A[0]*B[1]+A[1]*B[3], A[2]*B[0]+A[3]*B[2],A[2]*B[1]+ A[3]*B[3]]

print(C)

# %% [markdown]
# ### Questão 4
# Escreva um trecho de código Python que solicite três frases ao usuário. Para cada frase, você (seu programa) deve contar a frequência das palavras, sem considerar diferenças entre letras maiúsculas e minúsculas (Tudo = tudo). Exemplo com uma frase:
# Frase 1--> Oi. Tudo bem? Está tudo certo?
#   Oi: 1 (aparece uma vez na frase);
#   Tudo: 2 (aparecem 2 vezes);
#   bem: 1 (aparece uma vez na frase);
#   certo: 1 (aparece uma vez na frase);
#   está: 1 (aparece uma vez na frase).
#
# Como o enunciado fala em 3 (três frases) você deve contar a frequência **total** de aparecimento de cada palavra (considerando todas as frases) e  apresentar na tela cada uma das palavras identificadas
# e suas respectivas frequências. É **desnecessário** fazer qualquer tratamento envolvendo sinais de pontuação. Ou seja, você pode optar por separar e guardar as palavras quando encontrar um espaço em branco. Nesta questão, podemos considerar que uma 'string' é diferente de uma 'palavra' (do ponto de visa léxico gramatical). Quer dizer, a string "Oi." é diferente da string/palavra "oi" ou de "oI". Não há problema, você pode contar o "Oi." como uma aparição, um "oi" como uma outra aparição e um "oI" como uma outra.
#
#
# 1. Dica 1: pode usar a função `casefold` para remove qualquer a formatação das strings.
# 2. Dica 2: pode usar a função `split` para separar as strings por um determinado argumento, por exemplo um único espaço em branco: `split (' ')`
# 3. Pode usar Bag of words

# %%
# Escreva aqui a resposta da questão 4
# Recebe as frases
frase1 = str(input('Digite a primeira frase '))
frase2 = str(input("Digite a segunda frase "))
frase3 = str(input("Digite a terceira frase "))
# Cria uma variavel com as 3 frases juntas
frase = (frase1 +' '+ frase2 +' '+ frase3).split() 
contador = {}
for k in frase:
    contador.setdefault(k, 0)
    contador[k] += 1
for k, v in contador.items():
    print(f'A palavra "{k}" aparece {v} vez(es) na frase')

# %% [markdown]
# ### Questão 5
# Escreva um trecho de código Python que solicite três _strings_ ao usuário (uma entrada por vez). O usuário poderá fornecer tanto números inteiros como de ponto flutuante (float). Indepedente das entradas estarem ou não ordenadas de forma crescente (do menor número para o maior), o programa deve realizar este ordenamento crescente. Os valores já ordenados devem ser apresentados na tela como **um único conjunto** (valores de uma lista).
#
# Caso queira, você pode entrar com mais de um número por solicitação (na mesma linha da entrada de dados - mas lembre-se que ainda são 3 pedidos de input). Neste caso você pode pedir para que o usuário entre com os números separados por um único espaço e no seu código você pode tratar essa questão usando a função `split()`

# %%
# Escreva aqui a resposta da questão 5
# Solicita os tres inputs
l1 = float(input("Digite o primeiro valor "))
l2= float(input("Digite o segundo valor "))
l3= float(input("Digite o terceiro valor "))

lista = [l1, l2, l3] # cria uma lista com os 3 valores
print (sorted(lista)) # Utilizando a função sorted para colocar em ordem

# %% [markdown]
# ### Questão 6
# Escreva uma função Python chamada `dados_pessoais` que peça ao usuário os seguintes campos com dados pessoais:
# 1. Nome completo;
# 2. Gênero;
# 3. CPF.
#
# Os dados digitados devem ser retornados pela função na forma de um **dicionário Python**. No entanto, se qualquer um dos campos
# digitados for um _string_ vazio, o processo deve ser interrompido e a função deve retornar o valor `None`. Atenção: string vazio não é a mesma coisa que 'dar um espaço em branco'. Um espaço não é uma string vazia e uma string que contém um espaço.
#
# Um trecho de código Python deve ser escrito para demonstrar que a função efetivamente satisfaz suas especificações.
#
# 1. Dica 01: coloque a declaração da função logo no topo (no início) do código. Assim ela já será 'reconhecida' quando você chamá-la depois;
# 2. Dica 02: note no enunciado que os dados pessoais devem ser lidos dentro da função;
# 3. Dica 03: não é um _loop_. É apenas a entrada de três campos uma única vez.

# %%
# Escreva aqui a resposta da questão 6
nome = str(input("Digite seu nome "))
genero = str(input("Digite seu Gênero "))
cpf =str(input("Digite seu CPF "))
dados_pessoais = [nome, genero, cpf]
if nome !='' and genero !="" and cpf !='':
    print(dados_pessoais)
else: 
    print("None")

# %% [markdown]
# ### Questão 7
# Escreva uma função Python chamada `dados_ref()` que **receba** um _string_ correspondendo a uma referência bibliográfica, separe suas várias partes (o ponto pode ser utilizado como separador) e as retorne em um dicionário. As seguintes referências podem ser utilizadas como exemplo:
# 1. BELL, Robert A. Lingering questions and doubts: Online information-seeking of support forum members following their medical visits. Patient Education and Counseling. Dec 2011
# 2. BOOTH, Andrew. Searching for qualitative research for inclusion in systematic reviews: a structured methodological review: a structured methodological review. Systematic Reviews. May 2016
# 3. CENTRE FOR REVIEWS AND DISSEMINATION. Systematic Reviews: CRD’s guidance for undertaking reviews in health care. 2009
# 4. COOKE, Alison; SMITH, Debbie; BOOTH, Andrew. Beyond PICO: the SPIDER tool for qualitative evidence synthesis. Qualitative Health Research. July 2012
# 5. ERIKSEN, Mette Brandt; FRANDSEN, Tove Faber. The impact of patient, intervention, comparison, outcome (PICO) as a search strategy tool on literature search quality: a systematic review. Journal of The Medical Library Association. Oct 2018.
#
# O dicionário final deverá ter as seguintes chaves:
# 1. **`autores`**: os autores listados na referência; para o exemplo 1 acima seria `BELL, Robert A` e para o exemplo 3 seria `CENTRE FOR REVIEWS AND DISSEMINATION`;
# 2. **`titulo`**: o título da referência; para o exemplo 1 acima seria `Lingering questions and doubts: Online information-seeking of support forum members following their medical visits`, e para o exemplo 3 seria `Systematic Reviews: CRD’s guidance for undertaking reviews in health care`;
# 3. **`fonte`**: o periódico onde a referência foi publicada; para o exemplo 1 acima seria `Patient Education and Counseling` e para o exemplo 3 seria um _string_ vazio, pois não existe na referência;
# 4. **`data`**: o ano ou mês e ano da publicação; para o exemplo 1 acima seria `Dec 2011` e para o exemplo 3 seria `2009`.
#
# Um trecho de código Python deve ser escrito para demonstrar que a função efetivamente satisfaz suas especificações (podem imprimir na tela).
#
# 1. Dica 01: coloque a declaração da função logo no topo (no início) do código.
# 2. Dica 02: lembre-se das funções `split` e `strip`.

# %%
# Escreva aqui a resposta da questão 7
# Recebe o input com a referencia
referencia = str(input("Digite sua referencia: "))
# Separa a frase em pontos
lista = referencia.split(".")
# Cria um dicionario com chaves pré estabelecidas e os inputs  recebidos
dados_ref = {'author':lista[0], 'titulo':lista[1], "fonte":lista[2], 'data':lista[3]}
# Retorna a referencia bibliografica maior detalhado
print('\n','O author é',dados_ref["author"],'\n', 'O titulo do livro é',dados_ref["titulo"],'\n', 'A fonte é',dados_ref["fonte"],'\n', 'datado de',dados_ref['data'])

# %% [markdown]
# ### Questão 8
# Escreva uma função chamada `nome_biblio()` que **receba** um _string_ contendo um nome completo e o retorne na forma de uma referência bibliográfica. Por exemplo, se o nome completo fornecido for `Alex Sebastião Constâncio`, o retorno da função deverá ser `CONSTÂNCIO, A. S.`. Considere que todas as entradas de nomes terão o formado do exemplo (nomes completos e sem abreviações).
#
# Um trecho de código Python deve ser fornecido para pedir um número arbitrário de nomes completos. Um nome _string_ vazio deverá encerrar a repetição das entradas de nomes. Ao final, todos os nomes já convertidos para sua forma bibliográfica deverão ser mostrados na tela.

# %%
# Escreva aqui a resposta da questão 8
# Recebe o nome
nome = str(input('Digite seu nome: '))
# Transforma todas as letras em maiusculas
maiuscula = nome.upper()
# Separa as palavas
lista = maiuscula.split(' ')
primeiro =list(lista[0])
segundo = list(lista[1])
# Caso o segundo nome seja o ultimo
if lista[1] == lista[-1]:
    print (lista[-1]+ ",", primeiro[0]+".")
# Caso o segundo não seja o ultimo 
else:
    print (lista[-1]+ ",", primeiro[0]+".", segundo[0]+".")

# %% [markdown]
# ### Questão 9
# Escreva uma função chamada `acerto()` que **receba dois parâmetros**: uma palavra e uma letra. O retorno dessa função deverá ser um outro _string_ que identifique 'visualmente' onde a letra fornecida aparece e coloque um caracter de `_` (underline) onde não existir a letra. Por exemplo, se a chamada for `acerto("papaleguas", "a")` o resultado deverá ser `_a_a____a_`.
#
# Um trecho de código Python deve ser escrito para demonstrar que a função efetivamente satisfaz suas especificações.

# %%
# Escreva aqui a resposta da questão 9
# Recebe a palavra chave
chave = input("Digite a palavra ")
# Coloca as letras em uma lista
palavra_chave = list(chave)
letras_descobertas = []
# coloca "_" para cada letra da palavra chave
for i in range (0,len(palavra_chave)):
    letras_descobertas.append('_')
acerto = False
# Enquanto acerto for falso ele pedirá uma nova letra
while acerto == False:
    letra =str(input("Digite a letra: "))
    
    for i in range (0,len(palavra_chave)):
        if letra == palavra_chave[i]: 
            letras_descobertas[i]= letra
        print(letras_descobertas[i])
        
    acerto == True
    
    for x in range(0, len(letras_descobertas)):
        if letras_descobertas[x] == '_':
            acerto = False

# %% [markdown]
# ### Questão 10
# O **MatPlotLib** é um pacote do Python bastante utilizado para a geração de diagramas. Entre vários gráficos que o MatPlotLib permite gerar existe o _scatter_, que é um gráfico com pontos distribuídos em um plano Cartesiano (com eixos XY - horizontal e vertical). O código já existente na célula seguinte exemplifica o uso do MatPlotLib. Experimente executá-lo antes de iniciar a sua solução!
#
# Modifique o código Python existente/apresentado adicionando um _loop_ que solicite ao usuário um conjunto de _strings_, cada um contendo dois valores separados por espaço (num_x num_y). O usuário deverá fornecer um número arbitrário de pares. Um _string_ vazio termina o processo de entrada.
#
# Os pares digitados deverão ser colocados em listas distintas (uma representando o eixo X e outra representando o eixo Y) que então serão usadas para alimentar o MatPlotLib, substituindo as duas listas de valores já existentes no código.
#
# 1. Dica 01: você precisa importar o pacote MatPlotLib (e outros se for o caso) logo no início do código.

# %%
# Escreva aqui a resposta da questão 10
import matplotlib.pyplot as plt

# É a partir daqui  o código 'alterado' para a entrada de dados será colocado.
# A ideia é a  substitução às duas seguintes Linhas que estão já definindo as listas. Ou seja, depois de sua alteração
# tais linha podem ser comentadas ou apagadas.
x = 1
y = 0
listax = []
listay = []
while x!="":
    x = (input("Digite o valor de x "))
    y = (input("Digite o valor de y "))
    listay.append(y)
    listax.append(x)

# aqui embaixo é o código modificado para a reposta da questão. Ou seja, ao invés de considerar as listas acima, serão
# entrados novos dados pelo usuário

# Esse código fica como está, pois irá consumir os valores fornecidos pelo usuário
plt.scatter(listay[0:-1], listax[0:-1])
plt.show()
# Out:
# Digite o valor de x 5
# Digite o valor de y 3
# Digite o valor de x 2
# Digite o valor de y 4
# Digite o valor de x
# Digite o valor de y
